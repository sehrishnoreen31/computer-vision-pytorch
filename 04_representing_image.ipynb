# %%
import cv2, matplotlib.pyplot as plt
# %matplotlib inline

# %%
# converts image to array of pixel values
image = cv2.imread('/content/drive/MyDrive/CV/Images/colored.jpg')
image
# Out:
# array([[[148, 116,  41],
#         [148, 116,  41],
#         [148, 116,  41],
#         ...,
#         [115,  76,  37],
#         [118,  79,  40],
#         [121,  82,  43]],
#
#        [[147, 115,  40],
#         [147, 115,  40],
#         [147, 115,  40],
#         ...,
#         [114,  80,  37],
#         [118,  83,  43],
#         [121,  87,  44]],
#
#        [[144, 111,  38],
#         [144, 111,  38],
#         [144, 111,  38],
#         ...,
#         [109,  85,  39],
#         [112,  87,  43],
#         [115,  91,  45]],
#
#        ...,
#
#        [[ 32,  24,   1],
#         [ 32,  24,   1],
#         [ 32,  24,   1],
#         ...,
#         [ 67,  55,   7],
#         [ 67,  55,   7],
#         [ 67,  55,   7]],
#
#        [[ 31,  23,   0],
#         [ 31,  23,   0],
#         [ 31,  23,   0],
#         ...,
#         [ 67,  55,   7],
#         [ 66,  54,   6],
#         [ 66,  54,   6]],
#
#        [[ 31,  23,   0],
#         [ 31,  23,   0],
#         [ 31,  23,   0],
# ...

# %%
# crop image
croped_img = image[50:250, 40:240] # [rows range, cols range]
display(croped_img)
croped_img = image[100:250, 100:240] # [rows range, cols range]
display(croped_img)
# Out:
# array([[[154, 136, 153],
#         [157, 140, 154],
#         [162, 148, 160],
#         ...,
#         [198, 244, 255],
#         [186, 231, 255],
#         [183, 227, 255]],
#
#        [[166, 144, 156],
#         [171, 153, 160],
#         [168, 151, 154],
#         ...,
#         [134, 182, 234],
#         [141, 188, 240],
#         [137, 183, 231]],
#
#        [[138, 117, 109],
#         [104,  85,  70],
#         [ 66,  49,  28],
#         ...,
#         [ 57, 113, 192],
#         [ 68, 123, 204],
#         [ 71, 124, 204]],
#
#        ...,
#
#        [[ 10,   4,   0],
#         [ 11,   5,   0],
#         [ 14,   7,   0],
#         ...,
#         [ 51,  43,   3],
#         [ 49,  42,   0],
#         [ 48,  41,   0]],
#
#        [[ 10,   4,   0],
#         [ 11,   5,   0],
#         [ 14,   7,   0],
#         ...,
#         [ 51,  43,   3],
#         [ 50,  43,   0],
#         [ 48,  41,   0]],
#
#        [[ 10,   4,   0],
#         [ 11,   5,   0],
#         [ 14,   7,   0],
# ...

# %%
# convert to gray scale
gray_img = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
display(gray_img)d
# Out:
# array([[97, 97, 97, ..., 69, 72, 75],
#        [96, 96, 96, ..., 71, 75, 78],
#        [93, 93, 93, ..., 74, 77, 80],
#        ...,
#        [18, 18, 18, ..., 42, 42, 42],
#        [17, 17, 17, ..., 42, 41, 41],
#        [17, 17, 17, ..., 40, 39, 39]], dtype=uint8)

# %%
# display image with matplotlib
plt.imshow(image)

# %%
# resize image
small_img = cv2.resize(image, (50, 50))
# display(small_img)
plt.figure(figsize=(3,3))
plt.imshow(small_img) # gives a blurred image

# %%
# printing the pixels
print(small_img)
# Out:
# [[[146 114  39]
#   [146 114  40]
#   [150 117  43]
#   ...
#   [121  90  37]
#   [106  79  35]
#   [111  81  37]]
#
#  [[145 112  43]
#   [146 113  43]
#   [141 108  38]
#   ...
#   [ 95  75  44]
#   [ 95  78  48]
#   [104  85  79]]
#
#  [[141 108  46]
#   [136 102  41]
#   [125  93  30]
#   ...
#   [113  88 105]
#   [130  99 131]
#   [116  91  72]]
#
#  ...
#
#  [[ 22  15   1]
#   [ 27  21   2]
#   [ 32  28   4]
#   ...
#   [ 68  53   7]
#   [ 64  50   2]
#   [ 61  47   0]]
#
#  [[ 33  25   2]
#   [ 32  25   0]
#   [ 34  28   0]
#   ...
#   [ 69  57  10]
#   [ 66  55   4]
#   [ 61  49   1]]
#
#  [[ 31  23   0]
#   [ 33  26   0]
#   [ 35  29   0]
#   ...
#   [ 62  48   3]
#   [ 68  57   7]
#   [ 67  55   7]]]
